# %% [markdown]
# # AI in Speech Processing

# %% [markdown]
# #### Lab-1  1/2/2024

# %% [markdown]
# ### Name: Simhadri Tanya
# ### Reg No: BL.EN.U4AIE21119

# %%
import librosa

# %%
from IPython.display import Audio, display

# %%
filename = "C:\\Users\\Tanya Simhadri\\Downloads\\AI_in_Speech_Processing_recording.mpeg"
y, sr = librosa.load(filename)

# %%
librosa.display.waveshow(y)

# %%
# 1st Segment
filename = "C:\\Users\\Tanya Simhadri\\Downloads\\AI_in_Speech_Processing_recording.mpeg"
y1, sr1 = librosa.load(filename, offset=1.0, duration=1.0)

# %%
audio_segment1 = Audio(y1, rate=sr1)
display(audio_segment1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 2nd Segment
y2, sr2 = librosa.load(filename, offset=1.75, duration=3)

# %%
audio_segment2 = Audio(y2, rate=sr2)
display(audio_segment2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
