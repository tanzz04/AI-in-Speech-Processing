# %% [markdown]
# # Lab 6
# # Name: SImhadri Tanya
# # Reg No: BL.EN.U4AIE21119

# %%
import librosa
from IPython.display import Audio, display
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the audio signal
def load_signal(filename):
    y, sr = librosa.load(filename)
    return y,sr

# %% [markdown]
# ### VOWELS

# %%
# E
filename_e = "C:\\Users\\Tanya Simhadri\\Downloads\\vowel_e.wav"
y_e, sr_e = load_signal(filename_e)

# Play the audio_segment
audio = Audio(y_e, rate=sr_e)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_e = np.fft.fft(y_e, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_e)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'E' Speech Segment")
plt.show()

# %%
# I
filename_i = "C:\\Users\\Tanya Simhadri\\Downloads\\vowel_i.wav"
y_i, sr_i = load_signal(filename_i)

# Play the audio_segment
audio = Audio(y_i, rate=sr_i)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_i = np.fft.fft(y_i, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_i)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'I' Speech Segment")
plt.show()

# %%
# O
filename_o = "C:\\Users\\Tanya Simhadri\\Downloads\\vowel_o.wav"
y_o, sr_o = load_signal(filename_o)

# Play the audio_segment
audio = Audio(y_o, rate=sr_o)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_o = np.fft.fft(y_o, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_o)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'O' Speech Segment")
plt.show()

# %%
# U
filename_u = "C:\\Users\\Tanya Simhadri\\Downloads\\vowel_u.wav"
y_u, sr_u = load_signal(filename_u)

# Play the audio_segment
audio = Audio(y_u, rate=sr_u)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_u = np.fft.fft(y_u, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_u)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'U' Speech Segment")
plt.show()

# %% [markdown]
# ### CONSONANTS

# %%
# B
filename_b = "C:\\Users\\Tanya Simhadri\\Downloads\\consonant_b.wav"
y_b, sr_b = load_signal(filename_b)

# Play the audio_segment
audio = Audio(y_b, rate=sr_b)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_b = np.fft.fft(y_b, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_b)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'B' Speech Segment")
plt.show()

# %%
# K
filename_k = "C:\\Users\\Tanya Simhadri\\Downloads\\consonant_k.wav"
y_k, sr_k = load_signal(filename_k)

# Play the audio_segment
audio = Audio(y_k, rate=sr_k)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Calculate FFT
fft_k = np.fft.fft(y_k, n=None, axis=-1, norm=None)
amplitude = np.abs(fft_k)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the 'K' Speech Segment")
plt.show()

# %% [markdown]
# ### Silence and Non-voiced

# %%
# Non-voiced
filename = "C:\\Users\\Tanya Simhadri\\Downloads\\non_voiced.wav"
y, sr = load_signal(filename)

# Play the audio_segment
audio = Audio(y, rate=sr)
display(audio)

# Calculate FFT
fft = np.fft.fft(y, n=None, axis=-1, norm=None)
amplitude = np.abs(fft)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the Non voiced Speech Segment")
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Silence
filename = "C:\\Users\\Tanya Simhadri\\Downloads\\Silence.wav"
y, sr = load_signal(filename)

# Play the audio_segment
audio = Audio(y, rate=sr)
display(audio)

# Calculate FFT
fft = np.fft.fft(y, n=None, axis=-1, norm=None)
amplitude = np.abs(fft)

# Plot the amplitude spectrum
plt.plot(amplitude)
plt.title("Amplitude Spectrum of the Non voiced Speech Segment")
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# Load the audio file
filename = "C:\\Users\\Tanya Simhadri\\Downloads\\AI_in_Speech_Processing_recording.mpeg"
y,sr = load_signal(filename)

# Calculate the spectrogram
Spectrogram = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(12, 8))
librosa.display.specshow(Spectrogram, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()
